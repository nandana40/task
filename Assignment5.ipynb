# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Nandhana\Downloads\EMPLOYEE.xlsx")
df
# Out:
#     EmployeeID      Name     Age  Gender Department  Salary       City  \
# 0         1001     Rahul      22  Female        NaN   55000  Bangalore
# 1         1002     Kiran      31       M  Marketing     NaN    Calicut
# 2         1003       Anu  Thirty       F      Sales  48,000        NaN
# 3         1004      John      27       F  Marketing   35000    Calicut
# 4         1005     Aisha      25     NaN         IT  48,000        NaN
# ..         ...       ...     ...     ...        ...     ...        ...
# 95        1096       Anu      27    Male      Sales   42000      kochi
# 96        1097  Mohammed      29    Male         HR   35000        NaN
# 97        1098       Anu      22    Male         HR     NaN        NaN
# 98        1099     Arun       22  Female         IT   42000      Kochi
# 99        1100      Sara      31  Female        IT    55000        NaN
#
#       JoinDate Performance             Email
# 0          NaN       good     test@mail.com
# ...

# %%
df.head(10)
# Out:
#    employeeid       name  age   gender department   salary       city  \
# 0        1001      Rahul   22   Female  Marketing  55000.0  Bangalore
# 1        1002      Kiran   31     Male  Marketing  48000.0    Calicut
# 2        1003        Anu   30   Female      Sales  48000.0    Unknown
# 3        1004       John   27   Female  Marketing  35000.0    Calicut
# 4        1005      Aisha   25  Unknown         It  48000.0    Unknown
# 5        1006      Deepa   27   Female         Hr  48000.0    Unknown
# 6        1007      Priya   30  Unknown  Marketing  48000.0  Bangalore
# 7        1008      Aisha   27  Unknown  Marketing  48000.0    Unknown
# 8        1009  Mohammed    29     Male  Marketing  55000.0    Unknown
# 9        1010   Mohammed   25   Female         Hr  48000.0  Bangalore
#
#      joindate performance             email
# 0     Unknown        Good    Test@Mail.Com
# 1  2023-01-15     Unknown      Invalidemail
# 2     Unknown        Good    Test@Mail.Com
# ...

# %%
df.shape
# Out:
# (100, 10)

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Age', 'Gender', 'Department', 'Salary', 'City',
#        'JoinDate', 'Performance', 'Email'],
#       dtype='str')

# %%
df.dtypes
# Out:
# EmployeeID      int64
# Name              str
# Age            object
# Gender            str
# Department        str
# Salary         object
# City              str
# JoinDate          str
# Performance       str
# Email             str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   100 non-null    int64
#  1   Name         100 non-null    str
#  2   Age          82 non-null     object
#  3   Gender       75 non-null     str
#  4   Department   85 non-null     str
#  5   Salary       77 non-null     object
#  6   City         70 non-null     str
#  7   JoinDate     83 non-null     str
#  8   Performance  81 non-null     str
#  9   Email        75 non-null     str
# dtypes: int64(1), object(2), str(7)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#         EmployeeID
# count   100.000000
# mean   1050.400000
# std      29.151988
# min    1001.000000
# 25%    1025.750000
# 50%    1050.500000
# 75%    1075.250000
# max    1100.000000

# %%
df.nunique()
# Out:
# EmployeeID     99
# Name           18
# Age             6
# Gender          4
# Department      6
# Salary          4
# City            5
# JoinDate        3
# Performance     4
# Email           3
# dtype: int64

# %%
df.isna().sum()
# Out:
# employeeid     0
# name           0
# age            0
# gender         0
# department     0
# salary         0
# city           0
# joindate       0
# performance    0
# email          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["EmployeeID"].duplicated().sum()
# Out:
# np.int64(1)

# %%
df.columns=df.columns.str.lower()
df.columns
# Out:
# Index(['employeeid', 'name', 'age', 'gender', 'department', 'salary', 'city',
#        'joindate', 'performance', 'email'],
#       dtype='str')

# %%
df.columns.str.replace(" ","_",regex=False)
df.columns
# Out:
# Index(['employeeid', 'name', 'age', 'gender', 'department', 'salary', 'city',
#        'joindate', 'performance', 'email'],
#       dtype='str')

# %%
df["name"]=df["name"].str.title()
df["department"]=df["department"].str.title()
df["city"]=df["city"].str.title()
df["gender"]=df["gender"].str.title()
df["performance"]=df["performance"].str.title()
df["email"]=df["email"].str.title()
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["age"].apply(type).value_counts()
# Out:
# age
# <class 'int'>    99
# Name: count, dtype: int64

# %%
df["age"] = df["age"].replace("Thirty", 30)
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["age"] = df["age"].fillna(df["age"].median())
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["age"] = df["age"].astype(int)
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["age"].apply(type).value_counts()
# Out:
# age
# <class 'int'>    100
# Name: count, dtype: int64

# %%
df["age"] = df["age"].fillna(df["age"].mean())
df
# Out:
#     employeeid      name  age  gender department  salary       city  \
# 0         1001     Rahul   22  Female        NaN   55000  Bangalore
# 1         1002     Kiran   31       M  Marketing     NaN    Calicut
# 2         1003       Anu   30       F      Sales  48,000        NaN
# 3         1004      John   27       F  Marketing   35000    Calicut
# 4         1005     Aisha   25     NaN         It  48,000        NaN
# ..         ...       ...  ...     ...        ...     ...        ...
# 95        1096       Anu   27    Male      Sales   42000      Kochi
# 96        1097  Mohammed   29    Male         Hr   35000        NaN
# 97        1098       Anu   22    Male         Hr     NaN        NaN
# 98        1099     Arun    22  Female         It   42000      Kochi
# 99        1100      Sara   31  Female        It    55000        NaN
#
#       joindate performance             email
# 0          NaN       Good     Test@Mail.Com
# 1   2023-01-15         NaN      Invalidemail
# ...

# %%
df["salary"].apply(type).value_counts()
# Out:
# salary
# <class 'int'>      63
# <class 'float'>    23
# <class 'str'>      14
# Name: count, dtype: int64

# %%
df["salary"] = df["salary"].replace(",", "", regex=True)
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["salary"] = df["salary"].astype(float)
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["salary"] = df["salary"].fillna(df["salary"].median())
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["department"] = df["department"].fillna(df["department"].mode()[0])
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["city"] = df["city"].fillna("Unknown")
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["gender"] = df["gender"].fillna("Unknown")
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["performance"] = df["performance"].fillna("Unknown")
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["email"] = df["email"].fillna("Unknown")
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["salary"] = pd.to_numeric(df["salary"])
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["salary"] = df["salary"].replace("N/A", None)
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["salary"].dtype
# Out:
# dtype('float64')

# %%
df["gender"] = df["gender"].replace({
    "M": "Male",
    "F": "Female"
})
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["gender"] = df["gender"].fillna("Unknown")
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["joindate"] = df["joindate"].str.replace("/""-",regex=False)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 df["joindate"] = df["joindate"].str.replace("/""-",regex=False)
#       2 df
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\strings\accessor.py:142, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     137     msg = (
#     138         f"Cannot use .str.{func_name} with values of "
#     139         f"inferred dtype '{self._inferred_dtype}'."
#     140     )
#     141     raise TypeError(msg)
# --> 142 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\strings\accessor.py:1790, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
#    1788 # Check whether repl is valid (GH 13438, GH 15055)
# ...

# %%
df["city"] = df["city"].str.strip().str.title()
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["city"] = df["city"].fillna("Unknown")
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["department"] = df["department"].str.strip().str.title()
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["department"] = df["department"].replace("", "Unknown")
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["performance"] = df["performance"].str.strip().str.title()
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["performance"] = df["performance"].fillna("Unknown")
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df["performance"].value_counts()
# Out:
# performance
# Good         42
# Excellent    20
# Unknown      19
# Poor         18
# Name: count, dtype: int64

# %%
df = df.drop_duplicates(subset="employeeid", keep="first")
df
# Out:
#     employeeid      name  age   gender department   salary       city  \
# 0         1001     Rahul   22   Female  Marketing  55000.0  Bangalore
# 1         1002     Kiran   31     Male  Marketing  48000.0    Calicut
# 2         1003       Anu   30   Female      Sales  48000.0    Unknown
# 3         1004      John   27   Female  Marketing  35000.0    Calicut
# 4         1005     Aisha   25  Unknown         It  48000.0    Unknown
# ..         ...       ...  ...      ...        ...      ...        ...
# 95        1096       Anu   27     Male      Sales  42000.0      Kochi
# 96        1097  Mohammed   29     Male         Hr  35000.0    Unknown
# 97        1098       Anu   22     Male         Hr  48000.0    Unknown
# 98        1099     Arun    22   Female         It  42000.0      Kochi
# 99        1100      Sara   31   Female         It  55000.0    Unknown
#
#       joindate performance             email
# 0      Unknown        Good    Test@Mail.Com
# ...

# %%
df.shape
# Out:
# (99, 10)
