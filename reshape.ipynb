# %%
import numpy as np

# %%
a=np.array([1,2,4,3,5,6])
a.shape
# Out:
# (6,)

# %%
#@ 1D to 2D
a=np.array([2,1,4,5,6,2])
b=a.reshape(2,3) #(1,6),(6,1),(3,2)
print(a)
print(b)
# Out:
# [2 1 4 5 6 2]
# [[2 1 4]
#  [5 6 2]]

# %%
#1D TO 3D
c=np.array([1,2,4,3,5,7])
d=c.reshape(1,2,3)
print(d)
# Out:
# [[[1 2 4]
#   [3 5 7]]]

# %%
# 2D to 1D
a=np.array([[1,2],[3,4],[5,6],[8,7]])
e=a.reshape(8,)
e
# Out:
# array([1, 2, 3, 4, 5, 6, 8, 7])

# %%
#3D to 2D
a=np.array([[[2,3],[1,4],[5,7],[4,3]]])
b=a.reshape(4,2)
print(b)
# Out:
# [[2 3]
#  [1 4]
#  [5 7]
#  [4 3]]

# %%
#3D to 3D
a=np.array([[[2,3],[1,4],[5,7],[4,3]]])
b=a.reshape(1,2,4)
print(b)
# Out:
# [[[2 3 1 4]
#   [5 7 4 3]]]

# %%
#2D to 3D
a=np.array([[2,3],[1,4],[5,7],[4,3]])
b=a.reshape(1,2,4)
b
# Out:
# array([[[2, 3, 1, 4],
#         [5, 7, 4, 3]]])

# %%
#2D to 2D
a=np.array([[2,3],[1,4],[5,7],[4,2]])
b=a.reshape(4,2)
b
# Out:
# array([[2, 3],
#        [1, 4],
#        [5, 7],
#        [4, 2]])

# %%
#3 D to 1D 
a=np.array([[[2,3],[1,4],[5,7],[4,3]]])
c=a.reshape(8,)
print(c)
# Out:
# [2 3 1 4 5 7 4 3]

# %%
a=np.array([[[2,3],[1,4],[5,7],[4,3]]])
print(c)
a.flatten()
# Out:
# [2 3 1 4 5 7 4 3]
# array([2, 3, 1, 4, 5, 7, 4, 3])

# %%
a.reshape(-1)
# Out:
# array([2, 3, 1, 4, 5, 7, 4, 3])

# %%
a=np.array([5,4])
b=np.array([6,4])
c=np.add(a,b)
c
# Out:
# array([11,  8])

# %%
c=np.subtract(a,b)
c
# Out:
# array([-1,  0])

# %%
c=np.multiply(a,b)
c
# Out:
# array([30, 16])

# %%
c=np.dot(a,b)
c
# Out:
# np.int64(46)

# %%
a = np.array([1,5,80,6,43])
a.max()
# Out:
# np.int64(80)

# %%
a.min()
# Out:
# np.int64(1)

# %%
a.argmax()
# Out:
# np.int64(2)

# %%
a.argmin()
# Out:
# np.int64(0)

# %%
a.argmin(axis=0)
# Out:
# np.int64(0)

# %%
a.argmax(axis=0)#column
# Out:
# np.int64(2)

# %%
a = np.array([1,5,80,6,43])
b=a.copy()
b
# Out:
# array([ 1,  5, 80,  6, 43])

# %%
a[0]=4
a
# Out:
# array([ 4,  5, 80,  6, 43])

# %%
b
# Out:
# array([ 1,  5, 80,  6, 43])

# %%
a=np.array([7,8,6])

# %%
a[0]
# Out:
# np.int64(4)

# %%
a[0:2]
# Out:
# array([4, 5])

# %%
a[-3:-1]
# Out:
# array([80,  6])

# %%
a=np.array([
    [1,2],
    [6,9]
]
          )
a
# Out:
# array([[1, 2],
#        [6, 9]])

# %%
a[0,1]
# Out:
# np.int64(2)

# %%
a[-2,-1]
# Out:
# np.int64(2)

# %%
a=np.array([
    [1,2,6],
    [6,2,3]
]
          )
a
# Out:
# array([[1, 2, 6],
#        [6, 2, 3]])

# %%
a[0,2]
# Out:
# np.int64(6)

# %%
a[1,2]
# Out:
# np.int64(3)

# %%
c=np.array(
    [
        [[1,2,3],
        [4,5,6]],

        [[8,9,7],
        [4,5,6]],

        [[4,6,2],
        [4,5,9]],

    ]
)
c
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[8, 9, 7],
#         [4, 5, 6]],
#
#        [[4, 6, 2],
#         [4, 5, 9]]])

# %%
c[1,0,1]
# Out:
# np.int64(9)

# %%
c[-1,-2,-1]
# Out:
# np.int64(2)

# %%
c[0,0:2,1:3]
# Out:
# array([[2, 3],
#        [5, 6]])

# %%
c=np.array(
    [
        [1,2,3,5],
        [4,5,6,9],
        [8,2,1,10],
    ]
)
c
# Out:
# array([[ 1,  2,  3,  5],
#        [ 4,  5,  6,  9],
#        [ 8,  2,  1, 10]])

# %%
c[1:3,1:3]
# Out:
# array([[5, 6],
#        [2, 1]])

# %%
c[1:3,0:2]
# Out:
# array([[4, 5],
#        [8, 2]])
