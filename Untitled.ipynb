# %%
import numpy as np

# %%
a=np.array([
    [[1,2,3],
     [4,5,6],
     [7,4,5]]]
          )
a
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6],
#         [7, 4, 5]]])

# %%
a.reshape(3,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 4, 5]])

# %%
a[0,1:3,0:2]
# Out:
# array([[4, 5],
#        [7, 4]])
