# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Food":["Pizza","Burger","Pasta","Sandwich","Juice"],
    "Price":[250,180,220,150,100],
    "Orders":[50,70,40,80,60]
})
df
# Out:
#        Food  Price  Orders
# 0     Pizza    250      50
# 1    Burger    180      70
# 2     Pasta    220      40
# 3  Sandwich    150      80
# 4     Juice    100      60

# %%
len(df['Orders'])
# Out:
# 5

# %%
df[df['Food']=='Pizza']
# Out:
#     Food  Price  Orders
# 0  Pizza    250      50

# %%
df['Gst']=df['Price']* 0.05
df
# Out:
#        Food  Price  Orders   Gst
# 0     Pizza    250      50  12.5
# 1    Burger    180      70   9.0
# 2     Pasta    220      40  11.0
# 3  Sandwich    150      80   7.5
# 4     Juice    100      60   5.0
