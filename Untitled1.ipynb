# %%
df.head() Shows the first 5 rows of the DataFrame

# %%
df.tail() Shows the last 5 rows.

# %%
df.shape Returns (rows, columns)

# %%
df.columns

# %%
df.dtypes

# %%
df.info()  Displays column names, data types, and null value

# %%
df.describe() Shows statistics like mean, min, max, etc., for numeric column

# %%
df["Name"] Returns only the Name column

# %%
df[["Name", "Age"]] Returns only the selected columns

# %%
df.loc[2] Returns the row with index 2

# %%
df.loc[1:3, ["Name", "Age"]] Returns selected rows and selected columns

# %%
df.iloc[0] Returns the first row using its position.

# %%
df[df["Age"] > 20] Returns rows where Age is greater than 20

# %%
df[df["Name"] == "Anu"] Returns rows where Name is Anu

# %%
df.sort_values("Age") Sorts the DataFrame by Age.

# %%
df.sort_values("Age", ascending=False) Sorts from highest to lowest.

# %%
df["Grade"] = "A"  Adds a new column named Grade

# %%
df.loc[0, "Age"] = 25  Changes the Age of the first row

# %%
df.drop("Grade", axis=1) Removes the Grade column

# %%
df.drop(2) Removes the row with index 2

# %%
df.isnull().sum()  Counts missing values in each column.

# %%
df.dropna() Removes rows containing null values

# %%
df["City"].value_counts() Counts how many times each city appears

# %%
df["City"].unique() Returns all unique city names.

# %%
df["City"].nunique() Returns the number of unique cities

# %%
df.to_csv("output.csv", index=False) Saves the DataFrame to a new CSV file

# %%
df.loc[2, "Name"] : Returns the value in row 2 and column Name

# %%
df[(df["Age"] > 20) & (df["City"] == "Kochi")] Returns rows that satisfy both conditions

# %%
df.iloc[2, 1] Returns the value at row position 2 and column position 1

# %%
len(df) Returns the total number of rows

# %%
len(df.columns) Returns the total number of columns.

# %%
df["Salary"].max() Returns the highest value in the Salary column

# %%
df["Salary"].count() : Returns the number of non-null values.

# %%
df.rename(columns={"Name": "Student"}) Changes the column name.

# %%
df.set_index("ID") Makes the ID column the DataFrame index.

# %%
df.reset_index() Restores the default numeric index.

# %%
df.drop_duplicates()  Removes duplicate rows from the DataFrame

# %%
df[df["Name"] == "Anu"].index Returns the index of rows where Name is Anu

# %%
 df[2:6] Displays rows from index 2 to 5

# %%
df["City"].nunique() Returns the count of unique values in the City column

# %%
df["City"].unique() Returns all unique values in the City column.

# %%
df["City"].value_counts() Counts how many times each unique value appears

# %%
df.sort_values(by=["City", "Salary"]) Sorts the DataFrame first by City, then by Salary

# %%
df.loc[[0, 2, 4]] Returns only the specified rows

# %%
df.loc[:, ["Name", "Age"]]
