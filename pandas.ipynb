# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
marks = [7,4,3,2]
s = pd.Series(marks)
print(s)
# Out:
# 0    7
# 1    4
# 2    3
# 3    2
# dtype: int64

# %%
s = pd.Series(marks,index = ["A","B","C","D"])
print(s)
# Out:
# A    7
# B    4
# C    3
# D    2
# dtype: int64

# %%
a=pd.Series([1,2,3,4,5],dtype=float)
print(a)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
a=pd.Series([2,3,4,5,5]).astype(float)
print(a)
# Out:
# 0    2.0
# 1    3.0
# 2    4.0
# 3    5.0
# 4    5.0
# dtype: float64

# %%
s = pd.Series([5,7,4,98])
print(s[0])
print(s[1])
# Out:
# 5
# 7

# %%
s=pd.Series([29,6,25,])
print(s + 5)
print(s * 2)
# Out:
# 0    34
# 1    11
# 2    30
# dtype: int64
# 0    58
# 1    12
# 2    50
# dtype: int64

# %%
#common series functions
print(s.sum())
print(s.mean())
print(s.max())
print(s.min())
print(s.count())
# Out:
# 60
# 20.0
# 29
# 6
# 3

# %%
b = pd.Series([1,22,3,4,5])
print(a.add(b))
# Out:
# 0     3.0
# 1    25.0
# 2     7.0
# 3     9.0
# 4    10.0
# dtype: float64

# %%
#series to dataframe
b=pd.Series([11,2,12,13])
df=b.to_frame()
df
# Out:
#     0
# 0  11
# 1   2
# 2  12
# 3  13
